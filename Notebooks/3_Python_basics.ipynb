# %% [markdown]
# # Chapter 3 - Python basics
#
# *This notebook contains all the sample code in Chapter 3.*

# %% [markdown]
# ## Outline
#
# - [Code basics](#Code_basics)
#     - [Variables](#Variables)
#     - [Assigments](#Assigments)
#     - [Casting](#Casting)
#     - [Mathematical functions](#Math_fun)
#     - [Complex numbers](#Complex)
#     - [None value](#None)
#     - [Strings](#Strings)
#     - [User input](#User_input)
# - [Data structures](#Data_struc)
#     - [Lists](#Lists)
#     - [Tuples](#Tuples)
#     - [Sets](#Sets)
#     - [Dictionaries](#Dictionaries)
#     - [Files](#Files)
# - [Strings](#Strings)
#     - [String manipulation](#String_manipulation)
#     - [String formatting](#String_formatting)

# %% [markdown]
# ## Code basics <a id="Code_basics"></a>

# %% [markdown]
# ### Variables <a id="Variables"></a>

# %% [markdown]
# For creating **variables** in Python

# %%
a = 3
b = 4.2
C = -1.5

# %% [markdown]
# and then perform simple calculations:

# %%
b + 2
# Out:
# 6.2

# %%
a/2
# Out:
# 1.5

# %% [markdown]
# To *dinamycally* change the **data type**:

# %%
a = 3      # It is an integer
a = 'pq'   # It is a string
a = 5.4    # It is a float

# %% [markdown]
# The **type** of a variable can be checked by:

# %%
type(a)
# Out:
# float

# %%
type(b)
# Out:
# float

# %% [markdown]
# The semicolon can be used to make multiple assignments in a **single** line:

# %%
a = 3.1; b = 5.4; c = -0.4

# %% [markdown]
# To **display**  a variable in the *prompt*, use `print` function:

# %%
print(a)
# Out:
# 3.1

# %% [markdown]
# ### Assigments <a id="Assigments"></a>

# %% [markdown]
# Assignment is performed by the `=` symbol:

# %%
a = b + c

# %% [markdown]
# It is also possible to make **multiple**  assignments in a single line:

# %%
a, b = 1.3, 4.6

print(a)
print(b)
# Out:
# 1.3
# 4.6

# %% [markdown]
# This is very helpful to **swap**  two variables:

# %%
# Swapping two variables
a, b = b, a

# %% [markdown]
# When dealing with very large or very small values, we can use the so called scientific notation employing the `e` symbol:

# %%
a1 = 2e3
a2 = 3.47e+21  # The + symbol is optional
a3 = 7.21e-9

# %% [markdown]
# ### Casting <a id="Casting"></a>
#
# In some situations it is necessary to **convert**  values between different types:

# %%
int(2.8)
# Out:
# 2

# %%
int("3")
# Out:
# 3

# %%
float(5)
# Out:
# 5.0

# %%
float("4.3")
# Out:
# 4.3

# %%
str(5)
# Out:
# '5'

# %%
str(3.2)
# Out:
# '3.2'

# %% [markdown]
# ### Mathematical functions <a id="Math_fun"></a>
#
# Python provide different **built-in** mathematical functions:

# %%
abs(-3.8)
# Out:
# 3.8

# %%
divmod(10, 3)
# Out:
# (3, 1)

# %%
max(-3.2, 5, 4.1)
# Out:
# 5

# %%
min(-3.2, 5, 4.1)
# Out:
# -3.2

# %%
pow(4, 3)
# Out:
# 64

# %%
round(8.425, 1)
# Out:
# 8.4

# %% [markdown]
# For more advanced functions, it is necessary to **import** the `math` module:

# %%
import math

# %% [markdown]
# Now we can use all the **23**  functions contained in the module:

# %%
math.sqrt(16)
# Out:
# 4.0

# %%
math.log10(100)
# Out:
# 2.0

# %%
math.sin(math.pi/2)
# Out:
# 1.0

# %% [markdown]
# ### Complex numbers <a id="Complex"></a>
#
# Python supports **complex numbers**:

# %%
z = 3 + 2j

# %%
(1 + 2j)*(3 + 4j)
# Out:
# (-5+10j)

# %% [markdown]
# Otherwise, we can use the `complex()` function:

# %%
z = complex(3, 2)

# %% [markdown]
# The real and imaginary parts can be retrieved as:

# %%
z.real
# Out:
# 3.0

# %%
z.imag
# Out:
# 2.0

# %% [markdown]
# For mathematical functions with **complex numbers** , use the *complex-valued* version of the `math` module:

# %%
import cmath

# %% [markdown]
# For example, if we need to compute the **phase**  of a complex number *z*, we can use:

# %%
z = complex(3, 2)
p = cmath.phase(z)
print(p)
# Out:
# 0.5880026035475675

# %% [markdown]
# which is equivalent to $ \pi/4 $.

# %% [markdown]
# ### None value <a id="None"></a>
#
# Python defines a special value `None` to represent the absence of a value:

# %%
x = None
print(x)
# Out:
# None

# %% [markdown]
# However, in **comparisons** it is considered as `False`:

# %%
if x:
    print('True')
else:
    print('False')
# Out:
# False

# %% [markdown]
# ### Strings <a id="Strings"></a>
#
# Strings are defined by using single or double **quotes** (`'` or `"` ):

# %%
a = "hello"

# %% [markdown]
# For strings, the `+` operator performs **concatenation**:

# %%
'c' + 'd'
# Out:
# 'cd'

# %% [markdown]
# The use of the double quotes avoid the backslash for using the **apostrophe** :

# %%
x = "Don't need a backslash" 
x = 'Can\'t get by without a backslash'

# %% [markdown]
# ### User input <a id="User_input"></a>
#
# The `input()` function reads user input:

# %%
name = input("What is your name? ")
# Out:
# What is your name?  Michele

# %%
print(name)
# Out:
# Michele

# %% [markdown]
# Numeric input must be explicitly converted:

# %%
age = int(input("How old are you? "))
# Out:
# How old are you?  25

# %%
print(age)
# Out:
# 25

# %% [markdown]
# ## Data structures <a id="Data_struc"></a>

# %% [markdown]
# ### Lists <a id="Lists"></a>

# %% [markdown]
# A **list** is a collection of elements, enclosed in square brackets:

# %%
L1 = [0, 3, 2, 'hi']

# %% [markdown]
# Lists of lists:

# %%
L2 = [3, 2, [5, 4, 3], [2, 3, 2]]

# %% [markdown]
# Elements are accessed by index. **Python**  indices start at **0** :

# %%
L2[0]
# Out:
# 3

# %%
L2[1]
# Out:
# 2

# %% [markdown]
# However, we have also:

# %%
L2[2]
# Out:
# [5, 4, 3]

# %%
L2[3]
# Out:
# [2, 3, 2]

# %% [markdown]
# **Nested** elements require multiple indices:

# %%
L2[3][1]
# Out:
# 3

# %% [markdown]
# **Negative** indices allow access from the end:

# %%
L2[-1]
# Out:
# [2, 3, 2]

# %%
L2[-2]
# Out:
# [5, 4, 3]

# %% [markdown]
# A useful feature is the *slice* operator:

# %%
L2[2:4]
# Out:
# [[5, 4, 3], [2, 3, 2]]

# %% [markdown]
# The *slice* operator can include a step:

# %%
L2[0:4:2]
# Out:
# [3, [5, 4, 3]]

# %% [markdown]
# A list can be **reversed** using:

# %%
L2[::-1]
# Out:
# [[2, 3, 2], [5, 4, 3], 2, 3]

# %% [markdown]
# To **initialize** a list is simple to use:

# %%
L1 = [None] * 4
print(L1)
# Out:
# [None, None, None, None]

# %%
L2 = [3, 1] * 2
print(L2)
# Out:
# [3, 1, 3, 1]

# %%
L3 = [2] * 5
print(L3)
# Out:
# [2, 2, 2, 2, 2]

# %% [markdown]
# The **length** of a list is evaluated using the `len` command:

# %%
len(L2)
# Out:
# 4

# %% [markdown]
# For printing **only**  the elements of a list, **without**  the brackets:

# %%
L = [3, 2, 4, 1]
print(*L)
# Out:
# 3 2 4 1

# %% [markdown]
# Also for lists, the **+** operator produces the **concatenation**:

# %%
L1 = [3, 2, 4, 1]
L2 = [-2, 0, 5]

L = L1 + L2
print(L)
# Out:
# [3, 2, 4, 1, -2, 0, 5]

# %% [markdown]
# Elements can be **modified** via *assignment*:

# %%
L = [3, 2, 4, [1, -4], -5]

L[1] = 0
print(*L)
# Out:
# 3 0 4 [1, -4] -5

# %%
L[3:] = [-2, [0, 1]]
print(*L)
# Out:
# 3 0 4 -2 [0, 1]

# %%
L[1:3] = [5, None]
print(*L)
# Out:
# 3 5 None -2 [0, 1]

# %% [markdown]
# Similarly, one or more items can be **deleted**  by assigning them to the **empty**  list `[]`:

# %%
L[4] = []
print(*L)
# Out:
# 3 5 None -2 []

# %% [markdown]
# It is also possible to **add** new items at the **tail**  of a list:

# %%
L[len(L):] = [5, 6, 7]
print(*L)
# Out:
# 3 5 None -2 [] 5 6 7

# %% [markdown]
# However, this task can be **easily**  accomplished by using the `append()` method:

# %%
L.append(0)
print(*L)
# Out:
# 3 5 None -2 [] 5 6 7 0

# %% [markdown]
# To **check** if an element is **inside** a list:

# %%
L = [3, 2, 4, 1]

2 in L
# Out:
# True

# %%
0 in L
# Out:
# False

# %% [markdown]
# There are a variety of other **functions**  that can be applied to lists:

# %%
L.sort()
print(L)
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# The command itself produces **no output** . Rather, it modifies the list that can be printed on the prompt.

# %% [markdown]
# We provide other examples:

# %%
L = [4, 0, -2, 7, 0, 5]

L.count(0)
# Out:
# 2

# %%
L.index(0)
# Out:
# 1

# %%
L.extend([1, 2, 3])
print(L)
# Out:
# [4, 0, -2, 7, 0, 5, 1, 2, 3]

# %%
L.insert(2, 8)
print(L)
# Out:
# [4, 0, 8, -2, 7, 0, 5, 1, 2, 3]

# %%
L.pop(7)
# Out:
# 1

# %%
L.remove(0)
print(L)
# Out:
# [4, 8, -2, 7, 0, 5, 2, 3]

# %%
L.reverse()
print(L)
# Out:
# [3, 2, 5, 0, 7, -2, 8, 4]

# %%
max(L)
# Out:
# 8

# %%
min(L)
# Out:
# -2

# %%
sum(L)
# Out:
# 27

# %% [markdown]
# Because Python is object-oriented, all variable names are simply **references** to objects:

# %%
L1 = [3, 2, 4, 1]
L2 = L1
L2[2] = 10
print(L1)
# Out:
# [3, 2, 10, 1]

# %% [markdown]
# The slice operator can **partially** solve this issue:

# %%
L1 = [3, 2, 4, 1]
L2 = L1[:]
L2[2] = 10
print(L1)
# Out:
# [3, 2, 4, 1]

# %% [markdown]
# However, the previous trick **does not**  work properly in the case of lists of lists:

# %%
L1 = [3, 2, [5, 4, 3], [2, 3, 2]]
L2 = L1[:]
L2[2][1] = 10
print(L1)
# Out:
# [3, 2, [5, 10, 3], [2, 3, 2]]

# %% [markdown]
# The solution consists in performing a **deep copy** (instead of a **shallow copy**):

# %%
import copy

L1 = [3, 2, [5, 4, 3], [2, 3, 2]]
L2 = copy.deepcopy(L1)
L2[2][1] = 10
print(L1)
# Out:
# [3, 2, [5, 4, 3], [2, 3, 2]]

# %% [markdown]
# ### Tuples <a id="Tuples"></a>
#
# A **tuple** is an immutable list, defined using round brackets:

# %%
T = (0, 3, 'Jan', 'Feb', 'March')

# %% [markdown]
# Tuples support *indexing*, *printing*, and *length* evaluation:

# %%
print(T)
# Out:
# (0, 3, 'Jan', 'Feb', 'March')

# %%
print(*T)
# Out:
# 0 3 Jan Feb March

# %%
len(T)
# Out:
# 5

# %% [markdown]
# Also **tuples** can be **concatenated** using the **+** operator:

# %%
T1 = ('Jan', 'Feb', 'Mar')
T2 = ('Apr', 'May', 'Jun')

T = T1 + T2

# %% [markdown]
# Note that a tuple with a **single** elements needs of an additional **comma** after the element:

# %%
T = (5,)

# %% [markdown]
# A **tuple** can be **initialized**  in a single line:

# %%
(one, two, three, four) = (1, 2, 3, 4)

# %% [markdown]
# Tuple unpacking is also supported:

# %%
a, b = (1, 2)

# %% [markdown]
# **Conversion** between *lists* and *tuples* are possible:

# %%
list((1, 2, 3, 4))
# Out:
# [1, 2, 3, 4]

# %%
tuple([1, 2, 3, 4])
# Out:
# (1, 2, 3, 4)

# %% [markdown]
# The `tuple()` and `list()` commands are more **general**  and can be applied to **every** Python sequence:

# %%
list("Hello")
# Out:
# ['H', 'e', 'l', 'l', 'o']

# %% [markdown]
# ### Sets <a id="Sets"></a>
#
# A **set** is an unordered collections of **unique** items defined by curly brackets:

# %%
primes = {2, 3, 5, 7}
odds = {1, 3, 5, 7, 9}

# %% [markdown]
# Common operations include **union** , **intersection**, **difference**, and **symmetric difference**:

# %%
U = primes | odds    # Union
print(U)
# Out:
# {1, 2, 3, 5, 7, 9}

# %%
I = primes & odds    # Intersection
print(I)
# Out:
# {3, 5, 7}

# %%
D1 = primes - odds   # Difference (in primes but not in odds)
print(D1)
# Out:
# {2}

# %%
D2 = primes ^ odds   # Symmetric Difference (only in one set but not in both)
print(D2)
# Out:
# {1, 2, 9}

# %% [markdown]
# However, equivalent methods are also available:

# %%
U = primes.union(odds)         # Union
print(U)
# Out:
# {1, 2, 3, 5, 7, 9}

# %%
I = primes.intersection(odds)  # Intersection
print(I)
# Out:
# {3, 5, 7}

# %%
D = primes.difference(odds)    # Difference
print(D)
# Out:
# {2}

# %% [markdown]
# The number of element in a set is always obtained by the `len()` function:

# %%
len(primes)
# Out:
# 4

# %%
len(odds)
# Out:
# 5

# %% [markdown]
# A set can be **initialized** by a list or a tuple:

# %%
S = set([1, 2, 3, 1, 3, 5])

# %% [markdown]
# Then it is possible to **add**  or **remove** items:

# %%
S.add(4)
print(S)
# Out:
# {1, 2, 3, 4, 5}

# %%
S.remove(5)
print(S)
# Out:
# {1, 2, 3, 4}

# %% [markdown]
# Finally, we can **check** if an element is **inside** a set:

# %%
1 in S
# Out:
# True

# %%
5 in S
# Out:
# False

# %% [markdown]
# ### Dictionaries <a id="Dictionaries"></a>
#
# A dictionary stores key-value pairs and it is defined by the curly braces:

# %%
months = {'Jan': 31, 'Feb': 28, 'Mar': 31, 'Apr': 30} 
months['Feb']
# Out:
# 28

# %% [markdown]
# Also for dictionaries we can use the `print` command:

# %%
print(months)
# Out:
# {'Jan': 31, 'Feb': 28, 'Mar': 31, 'Apr': 30}

# %%
print(*months)
# Out:
# Jan Feb Mar Apr

# %% [markdown]
# There are some useful functions on **dictionaries**:

# %%
list(months.keys())
# Out:
# ['Jan', 'Feb', 'Mar', 'Apr']

# %%
list(months.values())
# Out:
# [31, 28, 31, 30]

# %%
list(months.items())
# Out:
# [('Jan', 31), ('Feb', 28), ('Mar', 31), ('Apr', 30)]

# %% [markdown]
# The number of elements in a dictionary is evaluated with the `len()` function, while the `in` keyword is used to check if a key is **inside** the dictionary:

# %%
len(months)
# Out:
# 4

# %%
'Feb' in months
# Out:
# True

# %%
'Jun' in months
# Out:
# False

# %%
30 in months
# Out:
# False

# %%
28 in months.values()
# Out:
# True

# %%
('Mar', 31) in months.items()
# Out:
# True

# %% [markdown]
# A dictionary is also **suitable** for storing sparse matrices:

# %%
mat = {(0,0): 3, (0,2): -2, (0,3): 11, (1,1): 9, (2,1): 7}

row = 1; col = 2
if (row, col) in mat:
    element = mat[(row, col)]
else:
	element = 0

print(element)
# Out:
# 0

# %% [markdown]
# ### Files <a id="Files"></a>

# %% [markdown]
# Files are **opened** by using the `open` function:

# %%
file = open('./data/myfile.txt', 'a')   # Open a file
file.write("Hello world!\n")             # Write something
file.close()                             # Close the file

# %% [markdown]
# In order to avoid to **close** manually the file, we can resort to a  **context manager** interface:

# %%
with open('./data/myfile.txt', 'a') as file:
    file.write("Hello world!\n")

# %%
with open('./data/myfile.txt', 'r') as file:
    line = file.readline()
    print(line)
# Out:
# Hello world!

# %% [markdown]
# ## Strings <a id="Strings"></a>

# %% [markdown]
# ### String manipulation <a id="String_manipulation"></a>
#
#
# **Strings** are sequences of characters:

# %%
x = "Goodbye!"

x[1]
# Out:
# 'o'

# %%
x[2:5]
# Out:
# 'odb'

# %%
x[:-1]
# Out:
# 'Goodbye'

# %%
len(x)
# Out:
# 8

# %%
x + " Bob"
# Out:
# 'Goodbye! Bob'

# %%
5 * "b"
# Out:
# 'bbbbb'

# %% [markdown]
# Special characters are included using **escape sequences**:

# %%
print("Some words followed by a tab \t and a new line\n")
# Out:
# Some words followed by a tab 	 and a new line

# %% [markdown]
# It is also possible to use any **ASCII** or **Unicode** character:

# %%
'\176'
# Out:
# '~'

# %%
'\x7E'
# Out:
# '~'

# %%
'\u007E'
# Out:
# '~'

# %% [markdown]
# **Casting** is also possible:

# %%
str(123.54)
# Out:
# '123.54'

# %%
float('54.32')
# Out:
# 54.32

# %%
int('103')
# Out:
# 103

# %% [markdown]
# To **check** if a string is composed by **numbers** or **characters**:

# %%
x = '125'
x.isdigit()
# Out:
# True

# %%
x.isalpha()
# Out:
# False

# %% [markdown]
# Python offers many methods working on **strings**:

# %%
x = "FIRST"
x.lower()
# Out:
# 'first'

# %%
y = "second"
y.upper()
# Out:
# 'SECOND'

# %%
z = "this is a simple sentence"
z.title()
# Out:
# 'This Is A Simple Sentence'

# %% [markdown]
# To **check** if a string is composed of **uppercase** or **owercase** characters:

# %%
x = 'THIRD'
x.isupper()
# Out:
# True

# %%
x.islower()
# Out:
# False

# %% [markdown]
# To **remove** **blank spaces**:

# %%
x = "    a sentence   with some blank   spaces      "
x.strip()
# Out:
# 'a sentence   with some blank   spaces'

# %%
x.lstrip()
# Out:
# 'a sentence   with some blank   spaces      '

# %%
x.rstrip()
# Out:
# '    a sentence   with some blank   spaces'

# %% [markdown]
# To **split** a string at blank spaces:

# %%
x = "This is a simple sentence"

x.split()
# Out:
# ['This', 'is', 'a', 'simple', 'sentence']

# %% [markdown]
# To **split** a string at specific occurrences of desired characters or sequence of characters:

# %%
x = "Beekeeper"

x.split("ee")
# Out:
# ['B', 'k', 'per']

# %% [markdown]
# For **concatenating** strings:

# %%
" ".join(["Words", "separated", "by", "spaces"])
# Out:
# 'Words separated by spaces'

# %%
"".join(["Words", "separated", "by", "nothing"])
# Out:
# 'Wordsseparatedbynothing'

# %%
"::".join(["Words", "separated", "by", "two", "colons"])
# Out:
# 'Words::separated::by::two::colons'

# %% [markdown]
# To **replace** all the occurrences of a sub-string with a new one:

# %%
x = "Beekeeper"

x.replace("ee", "+++")
# Out:
# 'B+++k+++per'

# %% [markdown]
# To finde **occurrence** in strings:

# %%
x = "Beekeeper"

x.find("ee")
# Out:
# 1

# %%
x.rfind("ee")
# Out:
# 4

# %%
x.find('pro')
# Out:
# -1

# %% [markdown]
# To **check** if a string **begins** or **ends** with a specific sub-string:

# %%
x.startswith("Beel")
# Out:
# False

# %%
x.endswith("per")
# Out:
# True

# %% [markdown]
# The number of **occurrences** of a character or a sub-string is:

# %%
x.count("ee")
# Out:
# 2

# %% [markdown]
# Finally, the `repr()` function returns a **printable representation** of an **object** in Python:

# %%
L = [1, 2, 3]
repr(L)
# Out:
# '[1, 2, 3]'

# %%
months = {'Jan':31, 'Feb':28, 'Mar':31, 'Apr':30}
repr(months)
# Out:
# "{'Jan': 31, 'Feb': 28, 'Mar': 31, 'Apr': 30}"

# %% [markdown]
# ### String formatting  <a id="String_formatting"></a>
#
# The `format` method considers using some brackets **marks** `{}` with positional numbers inside:

# %%
"A {0} triangle is composed of {1} equal {2}".format("isosceles", "two", "sides")
# Out:
# 'A isosceles triangle is composed of two equal sides'

# %% [markdown]
# To use variables inside:

# %%
w, h = 10, 5
S = w*h
"The surface of a rectangle of sides {0} and {1} is {2}".format(w, h, S)
# Out:
# 'The surface of a rectangle of sides 10 and 5 is 50'

# %% [markdown]
# It is also possible to assign some **names** to the marks:

# %%
"The surface of a rectangle of sides {width} and {height} is {surface}".format(width=w, height=h, surface=S)
# Out:
# 'The surface of a rectangle of sides 10 and 5 is 50'

# %% [markdown]
# The number *n* of characters allocated for printing can be **controlled** by:

# %%
"The surface is {0:>7}".format(S)
# Out:
# 'The surface is      50'

# %% [markdown]
# The **modulo** operator (`%`) is:

# %%
"A %s triangle is composed of %s equal %s" % ("isosceles", "two", "sides")
# Out:
# 'A isosceles triangle is composed of two equal sides'

# %% [markdown]
# Similarly, if we need to print **float** number:

# %%
"Surface is %f" % (5.65)
# Out:
# 'Surface is 5.650000'

# %% [markdown]
# We can **control**  the number of total digits and decimal digits by setting the **width** (`w`) and **precision** (`p`) fields:

# %%
"Surface is %6.2f" % (5.6534)
# Out:
# 'Surface is   5.65'

# %%
"Surface is %-6.2f" % (5.6534)
# Out:
# 'Surface is 5.65  '

# %% [markdown]
# The **modulo** operator can be also used for printing variables inside a **dictionary**:

# %%
numbers = {'e': 2.718, 'pi': 3.14159}
print("%(pi).2f -- %(pi).4f -- %(e).2f" % numbers)
# Out:
# 3.14 -- 3.1416 -- 2.72

# %% [markdown]
# The third and last approach is based on the string interpolation, or simply **f-strings**:

# %%
value = 42
message = f"The answer is simply {value}"
print(message)
# Out:
# The answer is simply 42

# %% [markdown]
# Also in this case we can use the width and precision fields:

# %%
pi = 3.14159
print(f"pi is {pi:{7}.{2}f}")
# Out:
# pi is    3.14
