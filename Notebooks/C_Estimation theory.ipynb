# %% [markdown]
# # Appendix C - Estimation theory
#
# *This notebook contains main information in Appendix C.*

# %% [markdown]
# Estimation theory concerns the inference of unknown quantities from observed data. This appendix summarizes the main concepts required in the book, including estimator properties, maximum-likelihood and Bayesian estimation, linear minimum mean-square estimation, and the Cramér-Rao lower bound.
