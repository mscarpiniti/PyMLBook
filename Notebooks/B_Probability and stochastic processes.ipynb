# %% [markdown]
# # Appendix B - Probability and stochastic processes
#
# *This notebook contains main information in Appendix B.*

# %% [markdown]
# This appendix summarizes the probability concepts used throughout the book. It is intended as a compact reference rather than a complete treatment. We first introduce events, random variables, and their principal statistics, and then extend these ideas to discrete-time stochastic processes.
